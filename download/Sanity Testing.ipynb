# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models

# %%
sensors = np.zeros((40, 40))
sensors_baseline = np.zeros((40, 40))
sensors_3d = np.zeros((40, 40, 40))

# %%
l = []
with open('matrix.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for r in row:
            l.append(r.split('_'))

# %%
num = 39
filename = './data/sphere/cyl_' + str(num) + '.csv'
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            if l[i][0] == "tsp":
                    sensors[int(l[i][1])][int(l[i][2])] = 1
            else:
                    sensors[int(l[i][0])][int(l[i][1]) + 13] = 1

plt.imshow(sensors)
plt.show()

# %%
num = 150
filename = './gen/' + str(num) + '.csv'
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            if l[i][0] == "tsp":
                    sensors[int(l[i][1])][int(l[i][2])] = 10 * float(row[4 * i])
            else:
                    sensors[int(l[i][0])][int(l[i][1]) + 13] = 10 * float(row[4 * i])

plt.imshow(sensors)
plt.show()

# %%
num = 350
filename = './gen/' + str(num) + '.csv'
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            if l[i][0] == "tsp":
                    sensors[int(l[i][1])][int(l[i][2])] = row[4 * i]
            else:
                    sensors[int(l[i][0])][int(l[i][1]) + 13] = row[4 * i]

plt.imshow(sensors)
plt.show()

# %%
li_x = list()
li_y = list()
li_z = list()
sensors = np.zeros((40, 40))
sensors_3d = np.zeros((40, 40, 40))
num = 550
filename = './gen2/Train/' + str(num) + '.csv'
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            li_x.append(float(row[4*i + 1]))
            li_y.append(float(row[4*i + 2]))
            li_z.append(float(row[4*i + 3]))
min_li_x = min(li_x)
max_li_x = max(li_x)
min_li_y = min(li_y)
max_li_y = max(li_y)
min_li_z = min(li_z)
max_li_z = max(li_z)
for i in range(len(li_x)):
    li_x[i] = int(39*((li_x[i] - min_li_x) / (max_li_x - min_li_x)))
    li_y[i] = int(39*((li_y[i] - min_li_y) / (max_li_y - min_li_y)))
    li_z[i] = int(39*((li_z[i] - min_li_z) / (max_li_z - min_li_z)))
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            sensors_3d[li_x[i]][li_y[i]][li_z[i]] = 1   
     
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim(0,40)
ax.set_ylim(0,40)
ax.set_zlim(0,40)
z, x, y = sensors_3d.nonzero()
ax.scatter(x, y, z, c=z, alpha=1)
plt.show()

# %%
li_x = list()
li_y = list()
li_z = list()
sensors = np.zeros((40, 40))
sensors_3d = np.zeros((40, 40, 40))
num = 350
filename = './gen2/Train/' + str(num) + '.csv'
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            li_x.append(float(row[4*i + 1]))
            li_y.append(float(row[4*i + 2]))
            li_z.append(float(row[4*i + 3]))
min_li_x = min(li_x)
max_li_x = max(li_x)
min_li_y = min(li_y)
max_li_y = max(li_y)
min_li_z = min(li_z)
max_li_z = max(li_z)
for i in range(len(li_x)):
    li_x[i] = int(39*((li_x[i] - min_li_x) / (max_li_x - min_li_x)))
    li_y[i] = int(39*((li_y[i] - min_li_y) / (max_li_y - min_li_y)))
    li_z[i] = int(39*((li_z[i] - min_li_z) / (max_li_z - min_li_z)))
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            sensors_3d[li_x[i]][li_y[i]][li_z[i]] = 1   
     
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim(0,40)
ax.set_ylim(0,40)
ax.set_zlim(0,40)
z, x, y = sensors_3d.nonzero()
ax.scatter(x, y, z, c=, alpha=1)
plt.show()

# %%
li_x = list()
li_y = list()
li_z = list()
li_dat = list()
sensors = np.zeros((40, 40))
sensors_3d = np.zeros((40, 40, 40))
num = 25
filename = './gen2/Train/' + str(num) + '.csv'
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            li_dat.append(float(row[4*i]))
            li_x.append(float(row[4*i + 1]))
            li_y.append(float(row[4*i + 2]))
            li_z.append(float(row[4*i + 3]))
min_li_dat = min(i for i in li_dat if i > 0)
max_li_dat = max(li_dat)
min_li_x = min(li_x)
max_li_x = max(li_x)
min_li_y = min(li_y)
max_li_y = max(li_y)
min_li_z = min(li_z)
max_li_z = max(li_z)
for i in range(len(li_x)):
    li_x[i] = int(39*((li_x[i] - min_li_x) / (max_li_x - min_li_x)))
    li_y[i] = int(39*((li_y[i] - min_li_y) / (max_li_y - min_li_y)))
    li_z[i] = int(39*((li_z[i] - min_li_z) / (max_li_z - min_li_z)))
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            sensors_3d[li_x[i]][li_y[i]][li_z[i]] = row[4*i]   
     
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim(0,40)
ax.set_ylim(0,40)
ax.set_zlim(0,40)
z, x, y = sensors_3d.nonzero()
c = np.zeros((len(z)))
for i in range(len(z)):
    c[i] = sensors_3d[x[i]][y[i]][z[i]]
ax.scatter(x, y, z, c=c, alpha=1)
plt.show()

# %%
li_x = list()
li_y = list()
li_z = list()
li_dat = list()
sensors = np.zeros((40, 40))
sensors_3d = np.zeros((40, 40, 40))
num = 225
filename = './gen2/Train/' + str(num) + '.csv'
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            li_dat.append(float(row[4*i]))
            li_x.append(float(row[4*i + 1]))
            li_y.append(float(row[4*i + 2]))
            li_z.append(float(row[4*i + 3]))
min_li_dat = min(i for i in li_dat if i > 0)
max_li_dat = max(li_dat)
min_li_x = min(li_x)
max_li_x = max(li_x)
min_li_y = min(li_y)
max_li_y = max(li_y)
min_li_z = min(li_z)
max_li_z = max(li_z)
for i in range(len(li_x)):
    li_x[i] = int(39*((li_x[i] - min_li_x) / (max_li_x - min_li_x)))
    li_y[i] = int(39*((li_y[i] - min_li_y) / (max_li_y - min_li_y)))
    li_z[i] = int(39*((li_z[i] - min_li_z) / (max_li_z - min_li_z)))
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
                sensors_3d[li_x[i]][li_y[i]][li_z[i]] = row[4 * i]   
     
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim(0,40)
ax.set_ylim(0,40)
ax.set_zlim(0,40)
z, x, y = sensors_3d.nonzero()
c = np.zeros((len(z)))
for i in range(len(z)):
    c[i] = sensors_3d[x[i]][y[i]][z[i]]
ax.scatter(x, y, z, c=c, alpha=1)
plt.show()

# %%
li_x = list()
li_y = list()
li_z = list()
li_dat = list()
sensors = np.zeros((40, 40))
sensors_3d = np.zeros((40, 40, 40))
num =425
filename = './gen2/Train/' + str(num) + '.csv'
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            li_dat.append(float(row[4*i]))
            li_x.append(float(row[4*i + 1]))
            li_y.append(float(row[4*i + 2]))
            li_z.append(float(row[4*i + 3]))
min_li_dat = min(i for i in li_dat if i > 0)
max_li_dat = max(li_dat)
min_li_x = min(li_x)
max_li_x = max(li_x)
min_li_y = min(li_y)
max_li_y = max(li_y)
min_li_z = min(li_z)
max_li_z = max(li_z)
for i in range(len(li_x)):
    li_x[i] = int(39*((li_x[i] - min_li_x) / (max_li_x - min_li_x)))
    li_y[i] = int(39*((li_y[i] - min_li_y) / (max_li_y - min_li_y)))
    li_z[i] = int(39*((li_z[i] - min_li_z) / (max_li_z - min_li_z)))
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
                sensors_3d[li_x[i]][li_y[i]][li_z[i]] = row[4*i]
     
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim(0,40)
ax.set_ylim(0,40)
ax.set_zlim(0,40)
z, x, y = sensors_3d.nonzero()
c = np.zeros((len(z)))
for i in range(len(z)):
    c[i] = sensors_3d[x[i]][y[i]][z[i]]
ax.scatter(x, y, z, c=c, alpha=1)
plt.show()

# %%
li_x = list()
li_y = list()
li_z = list()
sensors = np.zeros((40, 40))
sensors_3d = np.zeros((40, 40, 40))
num = 25
filename = './gen2/Validation/' + str(num) + '.csv'
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            li_x.append(float(row[4*i + 1]))
            li_y.append(float(row[4*i + 2]))
            li_z.append(float(row[4*i + 3]))

min_li_x = min(li_x)
max_li_x = max(li_x)
min_li_y = min(li_y)
max_li_y = max(li_y)
min_li_z = min(li_z)
max_li_z = max(li_z)
for i in range(len(li_x)):
    li_x[i] = int(39*((li_x[i] - min_li_x) / (max_li_x - min_li_x)))
    li_y[i] = int(39*((li_y[i] - min_li_y) / (max_li_y - min_li_y)))
    li_z[i] = int(39*((li_z[i] - min_li_z) / (max_li_z - min_li_z)))
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            sensors_3d[li_x[i]][li_y[i]][li_z[i]] = float(row[4*i])    
     
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim(0,40)
ax.set_ylim(0,40)
ax.set_zlim(0,40)
z, x, y = sensors_3d.nonzero()
ax.scatter(x, y, z, c=z, alpha=1)
plt.show()

# %%
li_x = list()
li_y = list()
li_z = list()
sensors = np.zeros((40, 40))
sensors_3d = np.zeros((40, 40, 40))
num = 125
filename = './gen2/Validation/' + str(num) + '.csv'
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            li_x.append(float(row[4*i + 1]))
            li_y.append(float(row[4*i + 2]))
            li_z.append(float(row[4*i + 3]))

min_li_x = min(li_x)
max_li_x = max(li_x)
min_li_y = min(li_y)
max_li_y = max(li_y)
min_li_z = min(li_z)
max_li_z = max(li_z)
for i in range(len(li_x)):
    li_x[i] = int(39*((li_x[i] - min_li_x) / (max_li_x - min_li_x)))
    li_y[i] = int(39*((li_y[i] - min_li_y) / (max_li_y - min_li_y)))
    li_z[i] = int(39*((li_z[i] - min_li_z) / (max_li_z - min_li_z)))
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            sensors_3d[li_x[i]][li_y[i]][li_z[i]] = float(row[4*i])    
     
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim(0,40)
ax.set_ylim(0,40)
ax.set_zlim(0,40)
z, x, y = sensors_3d.nonzero()
ax.scatter(x, y, z, c=z, alpha=1)
plt.show()

# %%
li_x = list()
li_y = list()
li_z = list()
sensors = np.zeros((40, 40))
sensors_3d = np.zeros((40, 40, 40))
num = 225
filename = './gen2/Validation/' + str(num) + '.csv'
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            li_x.append(float(row[4*i + 1]))
            li_y.append(float(row[4*i + 2]))
            li_z.append(float(row[4*i + 3]))

min_li_x = min(li_x)
max_li_x = max(li_x)
min_li_y = min(li_y)
max_li_y = max(li_y)
min_li_z = min(li_z)
max_li_z = max(li_z)
for i in range(len(li_x)):
    li_x[i] = int(39*((li_x[i] - min_li_x) / (max_li_x - min_li_x)))
    li_y[i] = int(39*((li_y[i] - min_li_y) / (max_li_y - min_li_y)))
    li_z[i] = int(39*((li_z[i] - min_li_z) / (max_li_z - min_li_z)))
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            sensors_3d[li_x[i]][li_y[i]][li_z[i]] = float(row[4*i])    
     
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim(0,40)
ax.set_ylim(0,40)
ax.set_zlim(0,40)
z, x, y = sensors_3d.nonzero()
ax.scatter(x, y, z, c=z, alpha=1)
plt.show()

# %%
li_x = list()
li_y = list()
li_z = list()
sensors = np.zeros((40, 40))
sensors_3d = np.zeros((40, 40, 40))
num = 80
filename = './gen/' + str(num) + '.csv'
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            li_x.append(float(row[4*i + 1]))
            li_y.append(float(row[4*i + 2]))
            li_z.append(float(row[4*i + 3]))
min_li_x = min(li_x)
max_li_x = max(li_x)
min_li_y = min(li_y)
max_li_y = max(li_y)
min_li_z = min(li_z)
max_li_z = max(li_z)
for i in range(len(li_x)):
    li_x[i] = int(39*((li_x[i] - min_li_x) / (max_li_x - min_li_x)))
    li_y[i] = int(39*((li_y[i] - min_li_y) / (max_li_y - min_li_y)))
    li_z[i] = int(39*((li_z[i] - min_li_z) / (max_li_z - min_li_z)))
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            sensors_3d[li_x[i]][li_y[i]][li_z[i]] = float(row[4*i])   
     
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim(0,40)
ax.set_ylim(0,40)
ax.set_zlim(0,40)
z, x, y = sensors_3d.nonzero()
ax.scatter(x, y, z, c=z, alpha=1)
plt.show()

# %%
num = 600
filename = './data/cyl_' + str(num) + '.csv'
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            sensors_3d[li_x[i]][li_y[i]][li_z[i]] = row[4*i]
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
z, x, y = sensors_3d.nonzero()

ax.scatter(x, y, z, c=z, alpha=1)
plt.show()

# %%
num = 500
filename = './data/box_' + str(num) + '.csv'
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            sensors_3d[li_x[i]][li_y[i]][li_z[i]] = row[4*i]
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
z, x, y = sensors_3d.nonzero()
ax.set_xlim(0,40)
ax.set_ylim(0,40)
ax.set_zlim(0,40)
ax.scatter(x, y, z, c=z, alpha=1)
plt.show()

# %%
num = 500
filename = './data/box_' + str(num) + '.csv'
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            if l[i][0] == "tsp":
                sensors[int(l[i][1])][int(l[i][2])] = row[4*i]
            else:
                sensors[int(l[i][0])][int(l[i][1]) + 13] = row[4*i]

plt.imshow(sensors)
plt.show()

# %%
num = 500
filename = './data/box_' + str(num) + '.csv'
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            sensors_3d[li_x[i]][li_y[i]][li_z[i]] = row[4*i]
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
z, x, y = sensors_3d.nonzero()
ax.set_xlim(0,40)
ax.set_ylim(0,40)
ax.set_zlim(0,40)
ax.scatter(x, y, z, c=z, alpha=1)
plt.show()

# %%
num = 153
filename = './data/box_' + str(num) + '.csv'
with open(filename, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
    for row in spamreader:
        for i in range(len(l)):
            if l[i][0] == "tsp":
                sensors[int(l[i][1])][int(l[i][2])] = 0.0001
                if float(row[4 * i]) > 0:
                    sensors[int(l[i][1])][int(l[i][2])] = row[4 * i]
            else:
                sensors[int(l[i][0])][int(l[i][1]) + 13] = 0.0001
                if float(row[4 * i]) > 0:
                    sensors[int(l[i][0])][int(l[i][1]) + 13] = row[4 * i]

plt.imshow(sensors)
plt.show()

# %%
for n in range(80):
    filename = './data/cyl_' + str(n) + '.csv'
    with open(filename, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='_')
        for row in spamreader:
            for i in range(len(l)):
                if l[i][0] == "tsp":
                    sensors[int(l[i][1])][int(l[i][2])] = row[4 * i]
                else:
                    sensors[int(l[i][0])][int(l[i][1]) + 13] = row[4 * i]

    plt.imshow(sensors)
    plt.show()
